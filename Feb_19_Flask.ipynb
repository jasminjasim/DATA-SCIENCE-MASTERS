# %% [markdown]
# # What is Flask Framework? What are the advantages of Flask Framework?

# %%
# Flask Framework is apython library uesd for creating Application Interfaces.
#Advantages is to connect with different application so that pass the values 
#from one to anoter

# %% [markdown]
# # Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask
# create an object fro the flak
app=Flask(__name__)
#use decorator
@app.route('/')
def print_hello():
    return("Hello,World!!")

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:ead33f7d-2abe-48e8-b4d9-3d45161f8c64.png)

# %% [markdown]
# # What is App routing in Flask? Why do we use app routes?

# %%
#Mapping the URL to a specific function.app routes are used to connect with API

# %% [markdown]
# # Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# * Company Name: ABC Corporation
# * Location: India
# * Contact Detail: 999-999-9999

# %%
#Create a “/welcome” route to display the welcome message 
# “Welcome to ABC Corporation” and a “/” route to show the following details:
#* Company Name: ABC Corporation
#* Location: India
#* Contact Detail: 999-999-9999
from flask import Flask
from flask import request

app=Flask(__name__)
@app.route('/welcome')
def welcome_func():
    return("Welcome to ABC Corporation")
@app.route('/')
def welcome_info():
    company_name=request.args.get('x')
    Location=request.args.get('y')
    Contact_details=request.args.get('z')
    return"Company Name:{}'\n'Location:{}'\n'Contact details:{}".format(company_name,Location,Contact_details)

if __name__=="__main__":
    app.run(host='0.0.0.0')

# %% [markdown]
# ![image.png](attachment:4f327f72-88bb-47a5-bbb5-0595ff674693.png)

# %% [markdown]
# # What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
#url_for is used to dynamically generate the url based on the context.

# %% [markdown]
# ![image.png](attachment:93dfcf6f-6f9a-41ee-a9de-3df7542fa026.png)![download.png](attachment:78feebfd-68d2-48af-87cf-d7bbd235c5b6.png)

# %%
from flask import Flask,url_for
from flask import request

app=Flask(__name__)
@app.route('/welcome/<Ownername>')
def welcome_func(Ownername):
    return("Welcome to ABC Corporation")
if __name__=="__main__":
    with app.test_request_context():
       print(url_for('welcome_func',Ownername='JASMIN'))
       app.run(host="0.0.0.0")
